# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject: United States Congress</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/us-congress/">https://discovery.cs.illinois.edu/microproject/us-congress/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">
#
# ## Introduction
#
# In this microproject, you will use Exploratory Data Analysis (EDA) techniques and the `groupby` function to find various statistics about the current legislators in the United States Congress.  Let's nerd out!

# %% [markdown]
# ## Dataset: "congress-legislators"
#
# The [@unitedstates project](https://theunitedstates.io/) maintains various high-quality datasets about the United States government.  Specifically, the `congress-legislators` dataset every member "of the United States Congress (1789-Present), congressional committees (1973-Present), committee membership (current only), and presidents and vice presidents of the United States in YAML, JSON, and CSV format."
#
# The URL for the CSV dataset is:
# ```
# https://theunitedstates.io/congress-legislators/legislators-current.csv
# ```
#
# Load the dataset into a DataFrame called `df`:

# %%
import pandas as pd
df=pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")
df
# Out:
#              last_name first_name middle_name suffix nickname  \
# 0                Brown    Sherrod         NaN    NaN      NaN
# 1             Cantwell      Maria         NaN    NaN      NaN
# 2               Cardin   Benjamin          L.    NaN      NaN
# 3               Carper     Thomas     Richard    NaN      NaN
# 4                Casey     Robert          P.    Jr.      Bob
# ..                 ...        ...         ...    ...      ...
# 536  Gluesenkamp Perez      Marie         NaN    NaN      NaN
# 537          Van Orden    Derrick     Francis    NaN      NaN
# 538            Hageman    Harriet      Maxine    NaN      NaN
# 539           Ricketts       Pete         NaN    NaN      NaN
# 540          McClellan   Jennifer         NaN    NaN      NaN
#
#                    full_name    birthday gender type state  ...  \
# 0              Sherrod Brown  1952-11-09      M  sen    OH  ...
# 1             Maria Cantwell  1958-10-13      F  sen    WA  ...
# 2         Benjamin L. Cardin  1943-10-05      M  sen    MD  ...
# 3           Thomas R. Carper  1947-01-23      M  sen    DE  ...
# 4       Robert P. Casey, Jr.  1960-04-13      M  sen    PA  ...
# ..                       ...         ...    ...  ...   ...  ...
# 536  Marie Gluesenkamp Perez  1988-06-06      F  rep    WA  ...
# 537        Derrick Van Orden  1969-09-15      M  rep    WI  ...
# 538       Harriet M. Hageman  1962-10-18      F  rep    WY  ...
# 539            Pete Ricketts  1964-08-19      M  sen    NE  ...
# 540    Jennifer L. McClellan  1972-12-28      F  rep    VA  ...
#
#      opensecrets_id  lis_id              fec_ids cspan_id govtrack_id  \
# 0         N00003535    S307  H2OH13033,S6OH00163   5051.0      400050
# 1         N00007836    S275  S8WA00194,H2WA01054  26137.0      300018
# 2         N00001955    S308  H6MD03177,S6MD03177   4004.0      400064
# 3         N00012508    S277            S8DE00079    663.0      300019
# 4         N00027503    S309            S6PA00217  47036.0      412246
# ..              ...     ...                  ...      ...         ...
# 536             NaN     NaN            H2WA03217      NaN      456949
# 537             NaN     NaN            H0WI03175      NaN      456950
# 538             NaN     NaN            H2WY00166      NaN      456951
# 539             NaN    S423            S6NE00129  61233.0      456952
# 540             NaN     NaN            H4VA04066      NaN      456953
#
#     votesmart_id           ballotpedia_id washington_post_id icpsr_id  \
# 0        27018.0            Sherrod Brown                NaN  29389.0
# 1        27122.0           Maria Cantwell                NaN  39310.0
# 2        26888.0               Ben Cardin                NaN  15408.0
# 3        22421.0               Tom Carper                NaN  15015.0
# 4         2541.0           Bob Casey, Jr.                NaN  40703.0
# ..           ...                      ...                ...      ...
# 536     207307.0  Marie Gluesenkamp Perez                NaN      NaN
# 537     192343.0        Derrick Van Orden                NaN      NaN
# 538     182961.0          Harriet Hageman                NaN      NaN
# 539      57777.0            Pete Ricketts                NaN      NaN
# 540      58655.0       Jennifer McClellan                NaN      NaN
#
#                 wikipedia_id
# 0              Sherrod Brown
# 1             Maria Cantwell
# 2                 Ben Cardin
# 3                 Tom Carper
# 4              Bob Casey Jr.
# ..                       ...
# 536  Marie Gluesenkamp Perez
# 537        Derrick Van Orden
# 538          Harriet Hageman
# 539            Pete Ricketts
# 540       Jennifer McClellan
#
# [541 rows x 36 columns]

# %% [markdown]
# ## Show All Columns
#
# This dataset has **A LOT** of columns!  By default, pandas will not show all of them.  By setting the `display.max_columns` value we can view all the columns:

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#              last_name first_name middle_name suffix nickname  \
# 0                Brown    Sherrod         NaN    NaN      NaN
# 1             Cantwell      Maria         NaN    NaN      NaN
# 2               Cardin   Benjamin          L.    NaN      NaN
# 3               Carper     Thomas     Richard    NaN      NaN
# 4                Casey     Robert          P.    Jr.      Bob
# ..                 ...        ...         ...    ...      ...
# 536  Gluesenkamp Perez      Marie         NaN    NaN      NaN
# 537          Van Orden    Derrick     Francis    NaN      NaN
# 538            Hageman    Harriet      Maxine    NaN      NaN
# 539           Ricketts       Pete         NaN    NaN      NaN
# 540          McClellan   Jennifer         NaN    NaN      NaN
#
#                    full_name    birthday gender type state  district  \
# 0              Sherrod Brown  1952-11-09      M  sen    OH       NaN
# 1             Maria Cantwell  1958-10-13      F  sen    WA       NaN
# 2         Benjamin L. Cardin  1943-10-05      M  sen    MD       NaN
# 3           Thomas R. Carper  1947-01-23      M  sen    DE       NaN
# 4       Robert P. Casey, Jr.  1960-04-13      M  sen    PA       NaN
# ..                       ...         ...    ...  ...   ...       ...
# 536  Marie Gluesenkamp Perez  1988-06-06      F  rep    WA       3.0
# 537        Derrick Van Orden  1969-09-15      M  rep    WI       3.0
# 538       Harriet M. Hageman  1962-10-18      F  rep    WY       0.0
# 539            Pete Ricketts  1964-08-19      M  sen    NE       NaN
# 540    Jennifer L. McClellan  1972-12-28      F  rep    VA       4.0
#
#      senate_class       party                                  url  \
# 0             1.0    Democrat         https://www.brown.senate.gov
# 1             1.0    Democrat      https://www.cantwell.senate.gov
# 2             1.0    Democrat        https://www.cardin.senate.gov
# 3             1.0    Democrat        https://www.carper.senate.gov
# 4             1.0    Democrat         https://www.casey.senate.gov
# ..            ...         ...                                  ...
# 536           NaN    Democrat  https://gluesenkampperez.house.gov/
# 537           NaN  Republican          https://vanorden.house.gov/
# 538           NaN  Republican           https://hageman.house.gov/
# 539           2.0  Republican      https://www.ricketts.senate.gov
# 540           NaN    Democrat                                  NaN
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 536  1431 Longworth House Office Building Washingto...  202-225-3536
# 537  1513 Longworth House Office Building Washingto...  202-225-5506
# 538  1531 Longworth House Office Building Washingto...  202-225-2311
# 539  40D Dirksen Senate Office Building Washington ...  202-224-4224
# 540  2417 Rayburn House Office Building Washington ...  202-225-6365
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 536                                                NaN
# 537                                                NaN
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 536                                                NaN           RepMGP
# 537                                                NaN      RepVanOrden
# 538                                                NaN              NaN
# 539                                                NaN              NaN
# 540                                                NaN              NaN
#
#        twitter_id             facebook           youtube  \
# 0    4.391080e+07  SenatorSherrodBrown  SherrodBrownOhio
# 1    1.175020e+08      senatorcantwell   SenatorCantwell
# 2    1.090710e+08     senatorbencardin     senatorcardin
# 3    2.497879e+08            tomcarper     senatorcarper
# 4    1.715987e+08      SenatorBobCasey   SenatorBobCasey
# ..            ...                  ...               ...
# 536  1.603128e+18                  NaN               NaN
# 537  1.598778e+18                  NaN               NaN
# 538           NaN                  NaN               NaN
# 539           NaN                  NaN               NaN
# 540           NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 536                       NaN      NaN     G000600        NaN            NaN
# 537                       NaN      NaN     V000135        NaN            NaN
# 538                       NaN      NaN     H001096        NaN            NaN
# 539                       NaN      NaN     R000618        NaN            NaN
# 540                       NaN      NaN     M001227        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 536    NaN            H2WA03217       NaN       456949      207307.0
# 537    NaN            H0WI03175       NaN       456950      192343.0
# 538    NaN            H2WY00166       NaN       456951      182961.0
# 539   S423            S6NE00129   61233.0       456952       57777.0
# 540    NaN            H4VA04066       NaN       456953       58655.0
#
#               ballotpedia_id  washington_post_id  icpsr_id  \
# 0              Sherrod Brown                 NaN   29389.0
# 1             Maria Cantwell                 NaN   39310.0
# 2                 Ben Cardin                 NaN   15408.0
# 3                 Tom Carper                 NaN   15015.0
# 4             Bob Casey, Jr.                 NaN   40703.0
# ..                       ...                 ...       ...
# 536  Marie Gluesenkamp Perez                 NaN       NaN
# 537        Derrick Van Orden                 NaN       NaN
# 538          Harriet Hageman                 NaN       NaN
# 539            Pete Ricketts                 NaN       NaN
# 540       Jennifer McClellan                 NaN       NaN
#
#                 wikipedia_id
# 0              Sherrod Brown
# 1             Maria Cantwell
# 2                 Ben Cardin
# 3                 Tom Carper
# 4              Bob Casey Jr.
# ..                       ...
# 536  Marie Gluesenkamp Perez
# 537        Derrick Van Orden
# 538          Harriet Hageman
# 539            Pete Ricketts
# 540       Jennifer McClellan
#
# [541 rows x 36 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Splitting The House of Representatives and The Senate
#
# In this dataset, each row is one member of Congress.  The United States Congress is bicameral, being made up of both the House of Representatives and the Senate.  In the dataset:
#
# - Representatives in the House of Representatives represent a district, which is encoded in the `district` column.  Their `type` column is also `rep`.
# - Senators are elected for six years, with one-third of the senators up for election every two years.  The `senate_class` denotes which election class a senator is in.  A seantor's `type` column is `sen`.
#
# Create two new DataFrames, `df_house` and `df_senate`, that contain members of the House of Representatives and the Senate:

# %%
df_house = df[df.type=="rep"]
df_house
# Out:
#              last_name first_name middle_name suffix nickname  \
# 27            Aderholt     Robert          B.    NaN      NaN
# 30           Bilirakis        Gus          M.    NaN      NaN
# 31              Bishop    Sanford          D.    Jr.      NaN
# 33          Blumenauer       Earl         NaN    NaN      NaN
# 36            Buchanan       Vern         NaN    NaN      NaN
# ..                 ...        ...         ...    ...      ...
# 535             Balint      Becca          A.    NaN      NaN
# 536  Gluesenkamp Perez      Marie         NaN    NaN      NaN
# 537          Van Orden    Derrick     Francis    NaN      NaN
# 538            Hageman    Harriet      Maxine    NaN      NaN
# 540          McClellan   Jennifer         NaN    NaN      NaN
#
#                    full_name    birthday gender type state  district  \
# 27        Robert B. Aderholt  1965-07-22      M  rep    AL       4.0
# 30          Gus M. Bilirakis  1963-02-08      M  rep    FL      12.0
# 31    Sanford D. Bishop, Jr.  1947-02-04      M  rep    GA       2.0
# 33           Earl Blumenauer  1948-08-16      M  rep    OR       3.0
# 36             Vern Buchanan  1951-05-08      M  rep    FL      16.0
# ..                       ...         ...    ...  ...   ...       ...
# 535             Becca Balint  1968-05-04      F  rep    VT       0.0
# 536  Marie Gluesenkamp Perez  1988-06-06      F  rep    WA       3.0
# 537        Derrick Van Orden  1969-09-15      M  rep    WI       3.0
# 538       Harriet M. Hageman  1962-10-18      F  rep    WY       0.0
# 540    Jennifer L. McClellan  1972-12-28      F  rep    VA       4.0
#
#      senate_class       party                                  url  \
# 27            NaN  Republican           https://aderholt.house.gov
# 30            NaN  Republican          https://bilirakis.house.gov
# 31            NaN    Democrat             https://bishop.house.gov
# 33            NaN    Democrat         https://blumenauer.house.gov
# 36            NaN  Republican           https://buchanan.house.gov
# ..            ...         ...                                  ...
# 535           NaN    Democrat            https://balint.house.gov/
# 536           NaN    Democrat  https://gluesenkampperez.house.gov/
# 537           NaN  Republican          https://vanorden.house.gov/
# 538           NaN  Republican           https://hageman.house.gov/
# 540           NaN    Democrat                                  NaN
#
#                                                address         phone  \
# 27   266 Cannon House Office Building Washington DC...  202-225-4876
# 30   2306 Rayburn House Office Building Washington ...  202-225-5755
# 31   2407 Rayburn House Office Building Washington ...  202-225-3631
# 33   1111 Longworth House Office Building Washingto...  202-225-4811
# 36   2110 Rayburn House Office Building Washington ...  202-225-5015
# ..                                                 ...           ...
# 535  1408 Longworth House Office Building Washingto...  202-225-4115
# 536  1431 Longworth House Office Building Washingto...  202-225-3536
# 537  1513 Longworth House Office Building Washingto...  202-225-5506
# 538  1531 Longworth House Office Building Washingto...  202-225-2311
# 540  2417 Rayburn House Office Building Washington ...  202-225-6365
#
#     contact_form                                            rss_url  \
# 27           NaN  http://aderholt.house.gov/common/rss//index.cf...
# 30           NaN  http://bilirakis.house.gov/index.php?format=fe...
# 31           NaN                    http://bishop.house.gov/rss.xml
# 33           NaN  http://blumenauer.house.gov/index.php?format=f...
# 36           NaN  http://buchanan.house.gov/index.php?option=com...
# ..           ...                                                ...
# 535          NaN                                                NaN
# 536          NaN                                                NaN
# 537          NaN                                                NaN
# 538          NaN                                                NaN
# 540          NaN                                                NaN
#
#              twitter    twitter_id             facebook           youtube  \
# 27   Robert_Aderholt  7.645276e+07       RobertAderholt    RobertAderholt
# 30   RepGusBilirakis  2.605168e+07         GusBilirakis   RepGusBilirakis
# 31     SanfordBishop  2.494105e+08        sanfordbishop  RepSanfordBishop
# 33   BlumenauerMedia  1.378240e+08                  NaN     RepBlumenauer
# 36      VernBuchanan  2.046716e+07  CongressmanBuchanan      vernbuchanan
# ..               ...           ...                  ...               ...
# 535        RepBeccaB  1.606115e+18                  NaN               NaN
# 536           RepMGP  1.603128e+18                  NaN               NaN
# 537      RepVanOrden  1.598778e+18                  NaN               NaN
# 538              NaN           NaN                  NaN               NaN
# 540              NaN           NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 27   UC71CAgpg1gbLTew_pfTneGA      NaN     A000055     1460.0      N00003028
# 30   UC2z1uu1n4-60xXs5x1mvLJw      NaN     B001257     1838.0      N00027462
# 31   UCxF9veLBrkr_CqVq5eFYVGg      NaN     B000490       91.0      N00002674
# 33   UCuziVoKuGn7feNA5VrpxsBQ      NaN     B000574       99.0      N00007727
# 36   UCY4DEy41NxOTdcF8_XAVZvw      NaN     B001260     1840.0      N00027626
# ..                        ...      ...         ...        ...            ...
# 535                       NaN      NaN     B001318        NaN            NaN
# 536                       NaN      NaN     G000600        NaN            NaN
# 537                       NaN      NaN     V000135        NaN            NaN
# 538                       NaN      NaN     H001096        NaN            NaN
# 540                       NaN      NaN     M001227        NaN            NaN
#
#     lis_id    fec_ids   cspan_id  govtrack_id  votesmart_id  \
# 27     NaN  H6AL04098    45516.0       400004         441.0
# 30     NaN  H6FL09070  1022873.0       412250       17318.0
# 31     NaN  H2GA02031    26194.0       400030       26817.0
# 33     NaN  H6OR03064    43809.0       400033         367.0
# 36     NaN  H6FL13148  1021626.0       412196       66247.0
# ..     ...        ...        ...          ...           ...
# 535    NaN  H2VT01076        NaN       456948      154056.0
# 536    NaN  H2WA03217        NaN       456949      207307.0
# 537    NaN  H0WI03175        NaN       456950      192343.0
# 538    NaN  H2WY00166        NaN       456951      182961.0
# 540    NaN  H4VA04066        NaN       456953       58655.0
#
#               ballotpedia_id  washington_post_id  icpsr_id  \
# 27        Robert B. Aderholt                 NaN   29701.0
# 30          Gus M. Bilirakis                 NaN   20758.0
# 31        Sanford Bishop Jr.                 NaN   29339.0
# 33           Earl Blumenauer                 NaN   29588.0
# 36             Vern Buchanan                 NaN   20709.0
# ..                       ...                 ...       ...
# 535                      NaN                 NaN       NaN
# 536  Marie Gluesenkamp Perez                 NaN       NaN
# 537        Derrick Van Orden                 NaN       NaN
# 538          Harriet Hageman                 NaN       NaN
# 540       Jennifer McClellan                 NaN       NaN
#
#                 wikipedia_id
# 27           Robert Aderholt
# 30             Gus Bilirakis
# 31            Sanford Bishop
# 33           Earl Blumenauer
# 36             Vern Buchanan
# ..                       ...
# 535             Becca Balint
# 536  Marie Gluesenkamp Perez
# 537        Derrick Van Orden
# 538          Harriet Hageman
# 540       Jennifer McClellan
#
# [441 rows x 36 columns]

# %%
df_senate = df[df.type=="sen"]
df_senate
# Out:
#      last_name    first_name middle_name suffix nickname  \
# 0        Brown       Sherrod         NaN    NaN      NaN
# 1     Cantwell         Maria         NaN    NaN      NaN
# 2       Cardin      Benjamin          L.    NaN      NaN
# 3       Carper        Thomas     Richard    NaN      NaN
# 4        Casey        Robert          P.    Jr.      Bob
# ..         ...           ...         ...    ...      ...
# 461      Britt         Katie   Elizabeth    NaN      NaN
# 462    Schmitt          Eric     Stephen    NaN      NaN
# 463      Vance  J.D. (James)     (David)    NaN      NaN
# 464  Fetterman          John        Karl    NaN      NaN
# 539   Ricketts          Pete         NaN    NaN      NaN
#
#                 full_name    birthday gender type state  district  \
# 0           Sherrod Brown  1952-11-09      M  sen    OH       NaN
# 1          Maria Cantwell  1958-10-13      F  sen    WA       NaN
# 2      Benjamin L. Cardin  1943-10-05      M  sen    MD       NaN
# 3        Thomas R. Carper  1947-01-23      M  sen    DE       NaN
# 4    Robert P. Casey, Jr.  1960-04-13      M  sen    PA       NaN
# ..                    ...         ...    ...  ...   ...       ...
# 461      Katie Boyd Britt  1982-02-02      F  sen    AL       NaN
# 462          Eric Schmitt  1975-06-20      M  sen    MO       NaN
# 463            J.D. Vance  1984-08-02      M  sen    OH       NaN
# 464        John Fetterman  1969-08-15      M  sen    PA       NaN
# 539         Pete Ricketts  1964-08-19      M  sen    NE       NaN
#
#      senate_class       party                               url  \
# 0             1.0    Democrat      https://www.brown.senate.gov
# 1             1.0    Democrat   https://www.cantwell.senate.gov
# 2             1.0    Democrat     https://www.cardin.senate.gov
# 3             1.0    Democrat     https://www.carper.senate.gov
# 4             1.0    Democrat      https://www.casey.senate.gov
# ..            ...         ...                               ...
# 461           3.0  Republican      https://www.britt.senate.gov
# 462           3.0  Republican    https://www.schmitt.senate.gov
# 463           3.0  Republican      https://www.vance.senate.gov
# 464           3.0    Democrat  https://www.fetterman.senate.gov
# 539           2.0  Republican   https://www.ricketts.senate.gov
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 461  B40A Dirksen Senate Office Building Washington...  202-224-5744
# 462  B11 Russell Senate Office Building Washington ...  202-224-5721
# 463  B40C Dirksen Senate Office Building Washington...  202-224-3353
# 464  B40B Dirksen Senate Office Building Washington...  202-224-4254
# 539  40D Dirksen Senate Office Building Washington ...  202-224-4224
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 461                      https://www.britt.senate.gov/
# 462                    https://www.schmitt.senate.gov/
# 463                      https://www.vance.senate.gov/
# 464                  https://www.fetterman.senate.gov/
# 539                                                NaN
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 461                                                NaN              NaN
# 462                                                NaN              NaN
# 463                                                NaN              NaN
# 464                                                NaN              NaN
# 539                                                NaN              NaN
#
#       twitter_id             facebook           youtube  \
# 0     43910797.0  SenatorSherrodBrown  SherrodBrownOhio
# 1    117501995.0      senatorcantwell   SenatorCantwell
# 2    109071031.0     senatorbencardin     senatorcardin
# 3    249787913.0            tomcarper     senatorcarper
# 4    171598736.0      SenatorBobCasey   SenatorBobCasey
# ..           ...                  ...               ...
# 461          NaN                  NaN               NaN
# 462          NaN                  NaN               NaN
# 463          NaN                  NaN               NaN
# 464          NaN                  NaN               NaN
# 539          NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 461                       NaN      NaN     B001319        NaN            NaN
# 462                       NaN      NaN     S001227        NaN            NaN
# 463                       NaN      NaN     V000137        NaN            NaN
# 464                       NaN      NaN     F000479        NaN            NaN
# 539                       NaN      NaN     R000618        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 461   S416            S2AL00145       NaN       456874      201704.0
# 462   S420            S2MO00544       NaN       456875      104474.0
# 463   S421            S2OH00436       NaN       456876           NaN
# 464   S418            S6PA00274       NaN       456877      166286.0
# 539   S423            S6NE00129   61233.0       456952       57777.0
#
#      ballotpedia_id  washington_post_id  icpsr_id    wikipedia_id
# 0     Sherrod Brown                 NaN   29389.0   Sherrod Brown
# 1    Maria Cantwell                 NaN   39310.0  Maria Cantwell
# 2        Ben Cardin                 NaN   15408.0      Ben Cardin
# 3        Tom Carper                 NaN   15015.0      Tom Carper
# 4    Bob Casey, Jr.                 NaN   40703.0   Bob Casey Jr.
# ..              ...                 ...       ...             ...
# 461     Katie Britt                 NaN       NaN     Katie Britt
# 462    Eric Schmitt                 NaN       NaN    Eric Schmitt
# 463      J.D. Vance                 NaN       NaN     J. D. Vance
# 464  John Fetterman                 NaN       NaN  John Fetterman
# 539   Pete Ricketts                 NaN       NaN   Pete Ricketts
#
# [100 rows x 36 columns]

# %% [markdown]
# ## 🔬 MicroProject Checkpoint Tests 🔬

# %%
### TEST CASE for Puzzle 1: Splitting The House of Representatives and The Senate
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
assert( len(df) > 500 ), "Your DataFrame `df` appears to not be the full dataset?  Did you modify `df` instead of creating a new `df_house` or `df_senate`?"
assert( len(df_senate) <= 100 ), "Your DataFrame `df_senate` contains more than 100 rows, but there should be 100 (or fewer) senators."
assert( len(df_house) == len(df) - len(df_senate) ), "Your DataFrame `df_house` does not contain everyone who isn't in the senate."
print(f"{tada} Puzzle 1: All Tests Passed! {tada}")
# Out:
# 🎉 Puzzle 1: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Find the Controlling Party of the House of Representatives
#
# In each body of Congress, the "controlling party" is the party that has the majority of the members.  Using `groupby`, create a DataFrame `df_house_party` that counts the number of members in each political party in the House of Representatives:

# %%
df_house_party = df_house.groupby("party").agg("count").reset_index()
df_house_party
# Out:
#         party  last_name  first_name  middle_name  suffix  nickname  \
# 0    Democrat        216         216          110       9         9
# 1  Republican        225         225          117       8        13
#
#    full_name  birthday  gender  type  state  district  senate_class  url  \
# 0        216       216     216   216    216       216             0  214
# 1        225       225     225   225    225       225             0  222
#
#    address  phone  contact_form  rss_url  twitter  twitter_id  facebook  \
# 0      216    216             0       93      199         199       122
# 1      225    225             0       64      203         203       107
#
#    youtube  youtube_id  mastodon  bioguide_id  thomas_id  opensecrets_id  \
# 0       86         110        15          216        110             182
# 1       62          95         0          225         87             184
#
#    lis_id  fec_ids  cspan_id  govtrack_id  votesmart_id  ballotpedia_id  \
# 0       0      216       123          216           200             173
# 1       0      225       108          225           193             176
#
#    washington_post_id  icpsr_id  wikipedia_id
# 0                   0       161           216
# 1                   0       135           225

# %% [markdown]
# ### Puzzle 2 Analysis: How many Democrats and Republicans in the House?
#
# Using the result above, fill out the following cell with the number of Democrats and Republications:

# %%
democrats_in_house = 216
republicans_in_house = 225

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Puzzle 2: Find the Controlling Party of the House of Representatives
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
R = df[ df.party == "Republican" ].head(1).index[0]
D = df[ df.party == "Democrat" ].head(1).index[0]
assert(len(df_house_party) == 2)
assert((df_house_party.index[0] == "Democrat" or df_house_party.index[0] == "Republican" or "party" in df.columns.tolist()))
assert(len(df) - len(df_senate) - df_house.value_counts(df.columns.tolist()[12])[df.sort_values(df.columns.tolist()[6]).iloc[R][df.columns.tolist()[12]]] == democrats_in_house)
assert(len(df) - len(df_senate) - df_house.value_counts(df.columns.tolist()[12])[df.sort_values(df.columns.tolist()[6]).iloc[D][df.columns.tolist()[12]]] == republicans_in_house)
print(f"{tada} Puzzle 2: All Tests Passed! {tada}")
# Out:
# 🎉 Puzzle 2: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Find the Youngest Member of each Party in the House of Representatives
#
# In the House of Representatives, who is the youngest member Democrat and who is the youngest Republican?
#
# **HINT**: To help with this, the `sort_values` function may be useful!  See our guide: ["Sorting a DataFrame Using Pandas"](https://discovery.cs.illinois.edu/guides/Modifying-DataFrames/sorting-a-dataframe-with-pandas/) to learn how to use the `sort_values` function.  You will be able to use the `sort_values` function to help solve this problem! :)

# %%
df_democrat=df[df.party=="Democrat"]
df_republican=df[df.party=="Republican"]
df_democrat.sort_values("birthday",ascending=False)
df_republican.sort_values("birthday",ascending=False)
# Out:
#         last_name first_name       middle_name suffix nickname  \
# 478  Paulina Luna       Anna         (Paulina)    NaN      NaN
# 516        Miller        Max           Leonard    NaN      NaN
# 508        Santos     George  Anthony Devolder    NaN      NaN
# 416      LaTurner      Jacob               NaN    NaN     Jake
# 401       Cammack  Katherine               NaN    NaN      Kat
# ..            ...        ...               ...    ...      ...
# 70        Granger        Kay               NaN    NaN      NaN
# 18      McConnell      Mitch               NaN    NaN      NaN
# 42         Carter       John                R.    NaN      NaN
# 132        Rogers     Harold               NaN    NaN      Hal
# 71       Grassley    Charles                E.    NaN    Chuck
#
#              full_name    birthday gender type state  district  senate_class  \
# 478  Anna Paulina Luna  1989-05-06      F  rep    FL      13.0           NaN
# 516      Max L. Miller  1988-11-13      M  rep    OH       7.0           NaN
# 508      George Santos  1988-07-22      M  rep    NY       3.0           NaN
# 416      Jake LaTurner  1988-02-17      M  rep    KS       2.0           NaN
# 401        Kat Cammack  1988-02-16      F  rep    FL       3.0           NaN
# ..                 ...         ...    ...  ...   ...       ...           ...
# 70         Kay Granger  1943-01-18      F  rep    TX      12.0           NaN
# 18     Mitch McConnell  1942-02-20      M  sen    KY       NaN           2.0
# 42      John R. Carter  1941-11-06      M  rep    TX      31.0           NaN
# 132      Harold Rogers  1937-12-31      M  rep    KY       5.0           NaN
# 71      Chuck Grassley  1933-09-17      M  sen    IA       NaN           3.0
#
#           party                               url  \
# 478  Republican           https://luna.house.gov/
# 516  Republican      https://maxmiller.house.gov/
# 508  Republican         https://santos.house.gov/
# 416  Republican        https://laturner.house.gov
# 401  Republican         https://cammack.house.gov
# ..          ...                               ...
# 70   Republican      https://kaygranger.house.gov
# 18   Republican  https://www.mcconnell.senate.gov
# 42   Republican          https://carter.house.gov
# 132  Republican       https://halrogers.house.gov
# 71   Republican   https://www.grassley.senate.gov
#
#                                                address         phone  \
# 478  1017 Longworth House Office Building Washingto...  202-225-5961
# 516  143 Cannon House Office Building Washington DC...  202-225-3876
# 508  1117 Longworth House Office Building Washingto...  202-225-3335
# 416  2441 Rayburn House Office Building Washington ...  202-225-6601
# 401  2421 Rayburn House Office Building Washington ...  202-225-5744
# ..                                                 ...           ...
# 70   2308 Rayburn House Office Building Washington ...  202-225-5071
# 18   317 Russell Senate Office Building Washington ...  202-224-2541
# 42   2208 Rayburn House Office Building Washington ...  202-225-3864
# 132  2406 Rayburn House Office Building Washington ...  202-225-4601
# 71   135 Hart Senate Office Building Washington DC ...  202-224-3744
#
#                                           contact_form  \
# 478                                                NaN
# 516                                                NaN
# 508                                                NaN
# 416                                                NaN
# 401                                                NaN
# ..                                                 ...
# 70                                                 NaN
# 18   https://www.mcconnell.senate.gov/public/index....
# 42                                                 NaN
# 132                                                NaN
# 71             https://www.grassley.senate.gov/contact
#
#                                                rss_url         twitter  \
# 478                                                NaN         RepLuna
# 516                                                NaN             NaN
# 508                                                NaN             NaN
# 416                                                NaN     RepLaTurner
# 401                                                NaN   RepKatCammack
# ..                                                 ...             ...
# 70                 http://kaygranger.house.gov/rss.xml   RepKayGranger
# 18   http://www.mcconnell.senate.gov/public/?a=rss....  McConnellPress
# 42          http://carter.house.gov/common/rss/?rss=40     JudgeCarter
# 132           http://halrogers.house.gov/news/rss.aspx    RepHalRogers
# 71    http://grassley.senate.gov/customcf/rss_feed.cfm   ChuckGrassley
#
#        twitter_id              facebook           youtube  \
# 478  1.610231e+18                   NaN               NaN
# 516           NaN                   NaN               NaN
# 508           NaN                   NaN               NaN
# 416  1.345851e+18                   NaN               NaN
# 401  1.344326e+18                   NaN               NaN
# ..            ...                   ...               ...
# 70   1.617437e+08         RepKayGranger     RepKayGranger
# 18   3.398229e+08        mitchmcconnell               NaN
# 42   1.803043e+07           judgecarter     repjohncarter
# 132  5.504018e+08  CongressmanHalRogers      RepHalRogers
# 71   1.061523e+07              grassley  senchuckgrassley
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 478                       NaN      NaN     L000596        NaN            NaN
# 516                       NaN      NaN     M001222        NaN            NaN
# 508                       NaN      NaN     S001222        NaN            NaN
# 416                       NaN      NaN     L000266        NaN      N00044232
# 401                       NaN      NaN     C001039        NaN      N00045978
# ..                        ...      ...         ...        ...            ...
# 70   UCsRMtemAkyLh78MPES6gMVQ      NaN     G000377     1487.0      N00008799
# 18                        NaN      NaN     M000355     1395.0      N00003389
# 42   UC9pkaOrhPfouzkJ8oAdI-1w      NaN     C001051     1752.0      N00025095
# 132  UChVFKLZkRoHQDhp4zNvEezQ      NaN     R000395      977.0      N00003473
# 71   UCiCPRkcLMInpDeOqGkMTt4w      NaN     G000386      457.0      N00001758
#
#     lis_id    fec_ids   cspan_id  govtrack_id  votesmart_id  \
# 478    NaN  H0FL13158        NaN       456891      191344.0
# 516    NaN  H2OH16051        NaN       456929      206947.0
# 508    NaN  H0NY03083        NaN       456921      191234.0
# 416    NaN  H0KS02188        NaN       456824           NaN
# 401    NaN  H0FL03175        NaN       456806           NaN
# ..     ...        ...        ...          ...           ...
# 70     NaN  H6TX12060    45709.0       400157         334.0
# 18    S174  S2KY00012     2351.0       300072       53298.0
# 42     NaN  H2TX31044  1004257.0       400068       49296.0
# 132    NaN  H0KY05015     6739.0       400340       26875.0
# 71    S153  S0IA00028     1167.0       300048       53293.0
#
#              ballotpedia_id  washington_post_id  icpsr_id  \
# 478       Anna Paulina Luna                 NaN       NaN
# 516                     NaN                 NaN       NaN
# 508  George Devolder-Santos                 NaN       NaN
# 416                     NaN                 NaN       NaN
# 401                     NaN                 NaN       NaN
# ..                      ...                 ...       ...
# 70              Kay Granger                 NaN   29762.0
# 18          Mitch McConnell                 NaN   14921.0
# 42              John Carter                 NaN   20356.0
# 132           Harold Rogers                 NaN   14854.0
# 71           Chuck Grassley                 NaN   14226.0
#
#                        wikipedia_id
# 478               Anna Paulina Luna
# 516         Max Miller (politician)
# 508                   George Santos
# 416                   Jake LaTurner
# 401                     Kat Cammack
# ..                              ...
# 70                      Kay Granger
# 18                  Mitch McConnell
# 42   John Carter (Texas politician)
# 132                      Hal Rogers
# 71                   Chuck Grassley
#
# [274 rows x 36 columns]

# %% [markdown]
# ### Puzzle 3 Analysis: How many Democrats and Republicans in the House?
#
# Using the result above, provide the **full name** (look for a column that contains `full_name`) of the youngest Democrat and Republican:

# %%
youngest_democrat_in_house = "Maxwell Frost"
youngest_republican_in_house = "Anna Paulina Luna"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## 🔬 MicroProject Checkpoint Tests 🔬

# %%
### TEST CASE for Puzzle 3: Find the Youngest Member of each Party in the House of Representatives
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
assert(df[ df.party == "Democrat" ].sort_values(df.columns.tolist()[6]).tail(1).values[0][5] == youngest_democrat_in_house)
assert(df[ df.party == "Republican" ].sort_values(df.columns.tolist()[6]).tail(1).values[0][5] == youngest_republican_in_house)
print(f"{tada} Puzzle 3: All Tests Passed! {tada}")
# Out:
# 🎉 Puzzle 3: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and return to https://discovery.cs.illinois.edu/microproject/us-congress/ and complete the section **"Commit and Grade Your Notebook"**.
#
# 3. If you see a 100% grade result on your GitHub Action, you've completed this MicroProject! 🎉
